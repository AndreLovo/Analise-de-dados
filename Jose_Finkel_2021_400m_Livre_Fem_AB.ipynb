# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreLovo/Analise-de-dados/blob/master/Jose_Finkel_2021_400m_Livre_Fem_AB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center> CAMPEONATO BRASILEIRO ABS DE NATAÇÃO - JOSÉ FINKEL - 2021 </center>
#
# <b>Fonte:</b> https://cbda.org.br/cbda/natacao/evento/34685/campeonato-brasileiro-abs-de-natacao-jose-finkel <br>
# <b>Arquivo 1-Documento CBDA:</b> "C:/Users/André Lovo/OneDrive/Área de Trabalho/Natação_Dados/CAMPEONATO_BRASILEIRO_ABS_NATACAO_JOSE_FINKEL_400m_LIVRE_FEMININO.pdf"
#
# <b>Arquivo2-Tabela de tempos:</b>
# <br>C:/Users/André Lovo/OneDrive/Área de Trabalho/Natação_Dados/tempos.xlsx <br>
#
# <br>
#
# ### Objetivos: <br>
# Fazer análise exploratória dos dados do Campeonato Brasileiro Abs de Natação - José Finkel - 2021

# %% [markdown]
# ### 1º - 400M LIVRE FEM. (AB)

# %%
# !pip install tabula-py
import tabula
from tabula import read_pdf
caminho = "drive/MyDrive/Colab Notebooks/Natação_Dados/CAMPEONATO_BRASILEIRO_ABS_NATACAO_JOSE_FINKEL_400m_LIVRE_FEMININO.pdf"

df = tabula.read_pdf(caminho, pages="all")

#Verificar quantas tabelas temos no arquivo

print(len(df))
# Out:
# ...
# Got stderr: May 12, 2022 8:00:26 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# May 12, 2022 8:00:26 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# May 12, 2022 8:00:26 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 17 fonts
# 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Passo importante - Código que já transforma o arquivo em formato  tabela 
for tabela in df:
    display(tabela)
# Out:
#                         RM                                    ARIARNE TITMUS  \
# 0                      RMJ                                        BINGJIE LI
# 1                       RS                     VIVIANE EICHELBERGER JUNGBLUT
# 2                       RB                     VIVIANE EICHELBERGER JUNGBLUT
# 3                       RC                     VIVIANE EICHELBERGER JUNGBLUT
# 4                      NaN                                               NaN
# 5                   Col. S                                 R Nome Patrocínio
# 6                      NaN                                               NaN
# 7                  Final A                                               NaN
# 8                     1° 1  4 GABRIELLE GONÇALVES RONCATTO MARINHA DO BRASIL
# 9                  RT: 0,8                                               NaN
# 10           25M: 00:27.89       50M: 00:42.76 (14.87) 75M: 00:57.86 (15.10)
# ...

# %%
#Separando as tabelas selecionadas pelo python no arquivo pdf
tabela1=df[0]
display(tabela1)
# Out:
#                         RM                                    ARIARNE TITMUS  \
# 0                      RMJ                                        BINGJIE LI
# 1                       RS                     VIVIANE EICHELBERGER JUNGBLUT
# 2                       RB                     VIVIANE EICHELBERGER JUNGBLUT
# 3                       RC                     VIVIANE EICHELBERGER JUNGBLUT
# 4                      NaN                                               NaN
# 5                   Col. S                                 R Nome Patrocínio
# 6                      NaN                                               NaN
# 7                  Final A                                               NaN
# 8                     1° 1  4 GABRIELLE GONÇALVES RONCATTO MARINHA DO BRASIL
# 9                  RT: 0,8                                               NaN
# 10           25M: 00:27.89       50M: 00:42.76 (14.87) 75M: 00:57.86 (15.10)
# ...

# %%
# Trabalhando a Tabela df[0]- Começa no indice ou linha 5
tabela1.columns = tabela1.iloc[5]
display(tabela1)
#Col = colocacao
#S = saida
#R = raia
#Nome=atleta
#Patrocinio=atrocinio
#Reg. C.= registro_conf
#Nasc.=ano_nascimento
#Entidade=Clube
#Tempo Obtido=tempo 
#Pts.=pontos
#IT
# Out:
# 5                   Col. S                                 R Nome Patrocínio  \
# 0                      RMJ                                        BINGJIE LI
# 1                       RS                     VIVIANE EICHELBERGER JUNGBLUT
# 2                       RB                     VIVIANE EICHELBERGER JUNGBLUT
# 3                       RC                     VIVIANE EICHELBERGER JUNGBLUT
# 4                      NaN                                               NaN
# 5                   Col. S                                 R Nome Patrocínio
# 6                      NaN                                               NaN
# 7                  Final A                                               NaN
# 8                     1° 1  4 GABRIELLE GONÇALVES RONCATTO MARINHA DO BRASIL
# 9                  RT: 0,8                                               NaN
# 10           25M: 00:27.89       50M: 00:42.76 (14.87) 75M: 00:57.86 (15.10)
# ...

# %%
#Selecionando os valores das linhas 8 até a 40
tabela1 = tabela1[8:40]
display(tabela1)
# Out:
# 5                   Col. S                                 R Nome Patrocínio  \
# 8                     1° 1  4 GABRIELLE GONÇALVES RONCATTO MARINHA DO BRASIL
# 9                  RT: 0,8                                               NaN
# 10           25M: 00:27.89       50M: 00:42.76 (14.87) 75M: 00:57.86 (15.10)
# 11  225M: 02:31.02 (15.79)     250M: 02:46.59 (15.57) 275M: 03:02.43 (15.84)
# 12                    2° 1     5 NATHALIA SIQUEIRA ALMEIDA MARINHA DO BRASIL
# 13                RT: 0,77                                               NaN
# 14           25M: 00:28.30       50M: 00:43.41 (15.11) 75M: 00:58.85 (15.44)
# 15  225M: 02:31.49 (15.68)     250M: 02:46.98 (15.49) 275M: 03:02.72 (15.74)
# 16                    3° 1                            3 MARIA PAULA HEITMANN
# 17                RT: 0,74                                               NaN
# 18           25M: 00:29.29       50M: 00:44.55 (15.26) 75M: 01:00.05 (15.50)
# ...

# %%
tabela1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 8 to 39
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Col. S             32 non-null     object
#  1   R Nome Patrocínio  24 non-null     object
#  2   Reg.               24 non-null     object
#  3   nan                0 non-null      float64
#  4   nan                0 non-null      float64
#  5   C. Nasc. Entidade  24 non-null     object
#  6   nan                16 non-null     object
#  7   nan                0 non-null      float64
#  8   Pts. IT            24 non-null     object
#  9   nan                8 non-null      object
# dtypes: float64(3), object(7)
# memory usage: 2.6+ KB

# %%
#Excluindo à partir das colunas axis e subsets as colunas
tabela1 = tabela1.dropna(axis=1, subset=[8])
display(tabela1)
# Out:
# 5                   Col. S                                 R Nome Patrocínio  \
# 8                     1° 1  4 GABRIELLE GONÇALVES RONCATTO MARINHA DO BRASIL
# 9                  RT: 0,8                                               NaN
# 10           25M: 00:27.89       50M: 00:42.76 (14.87) 75M: 00:57.86 (15.10)
# 11  225M: 02:31.02 (15.79)     250M: 02:46.59 (15.57) 275M: 03:02.43 (15.84)
# 12                    2° 1     5 NATHALIA SIQUEIRA ALMEIDA MARINHA DO BRASIL
# 13                RT: 0,77                                               NaN
# 14           25M: 00:28.30       50M: 00:43.41 (15.11) 75M: 00:58.85 (15.44)
# 15  225M: 02:31.49 (15.68)     250M: 02:46.98 (15.49) 275M: 03:02.72 (15.74)
# 16                    3° 1                            3 MARIA PAULA HEITMANN
# 17                RT: 0,74                                               NaN
# 18           25M: 00:29.29       50M: 00:44.55 (15.26) 75M: 01:00.05 (15.50)
# ...

# %%
tabela1 = tabela1.dropna()
display(tabela1)
#Col.= colocacao
#S = saida
#R = raia
#Nome=atleta
#Patrocinio=atrocinio
#Reg. C.= registro_conf
#Nasc.=ano_nascimento
#Entidade=Clube
#Tempo Obtido=tempo 
#Pts.=pontos
#IT
# Out:
# 5                   Col. S                                 R Nome Patrocínio  \
# 8                     1° 1  4 GABRIELLE GONÇALVES RONCATTO MARINHA DO BRASIL
# 10           25M: 00:27.89       50M: 00:42.76 (14.87) 75M: 00:57.86 (15.10)
# 11  225M: 02:31.02 (15.79)     250M: 02:46.59 (15.57) 275M: 03:02.43 (15.84)
# 12                    2° 1     5 NATHALIA SIQUEIRA ALMEIDA MARINHA DO BRASIL
# 14           25M: 00:28.30       50M: 00:43.41 (15.11) 75M: 00:58.85 (15.44)
# 15  225M: 02:31.49 (15.68)     250M: 02:46.98 (15.49) 275M: 03:02.72 (15.74)
# 16                    3° 1                            3 MARIA PAULA HEITMANN
# 18           25M: 00:29.29       50M: 00:44.55 (15.26) 75M: 01:00.05 (15.50)
# 19  225M: 02:33.41 (15.69)     250M: 02:49.04 (15.63) 275M: 03:04.79 (15.75)
# 20                    4° 1            7 ALINE DA SILVA RODRIGUES AERONÁUTICA
# 22           25M: 00:28.93       50M: 00:44.40 (15.47) 75M: 01:00.10 (15.70)
# ...

# %%
#Excluindo as tuplas/linhas
tabela1.drop([10,11,14,15,18,19,22,23,26,27,30,31,34,35,38,39], axis=0, inplace=True)
display(tabela1)
# Out:
# 5  Col. S                                 R Nome Patrocínio    Reg.  \
# 8    1° 1  4 GABRIELLE GONÇALVES RONCATTO MARINHA DO BRASIL  119052
# 12   2° 1     5 NATHALIA SIQUEIRA ALMEIDA MARINHA DO BRASIL  091438
# 16   3° 1                            3 MARIA PAULA HEITMANN  102920
# 20   4° 1            7 ALINE DA SILVA RODRIGUES AERONÁUTICA  084981
# 24   5° 1                        8 BEATRIZ PIMENTEL DIZOTTI  126635
# 28   6° 1                            2 SOFIA GARUFFI RONDEL  270127
# 32   7° 1                           6 GIOVANA REIS MEDEIROS  299900
# 36   8° 1                            1 GIULIA SALESI CHICON  250865
#
# 5        C. Nasc. Entidade             Pts. IT
# 8      1998 CR FLAMENGO/RJ  04:04.35 35,00 877
# 12     1996 CR FLAMENGO/RJ  04:04.66 30,00 874
# 16  1999 MINAS TENIS CLUBE  04:07.50 25,00 844
# 20  1995 MINAS TENIS CLUBE  04:12.25 20,00 797
# 24  2000 MINAS TENIS CLUBE  04:13.10 18,00 789
# 28        2002 CORINTHIANS  04:13.46 16,00 786
# ...

# %%
tabela1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 8 to 36
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Col. S             8 non-null      object
#  1   R Nome Patrocínio  8 non-null      object
#  2   Reg.               8 non-null      object
#  3   C. Nasc. Entidade  8 non-null      object
#  4   Pts. IT            8 non-null      object
# dtypes: object(5)
# memory usage: 384.0+ bytes

# %% [markdown]
# ### Entendendo as colunas

# %%
tabela1['Col. S']
# Out:
# 8     1° 1
# 12    2° 1
# 16    3° 1
# 20    4° 1
# 24    5° 1
# 28    6° 1
# 32    7° 1
# 36    8° 1
# Name: Col. S, dtype: object

# %%
tabela1['Pts. IT']
# Out:
# 8     04:04.35 35,00 877
# 12    04:04.66 30,00 874
# 16    04:07.50 25,00 844
# 20    04:12.25 20,00 797
# 24    04:13.10 18,00 789
# 28    04:13.46 16,00 786
# 32    04:14.00 14,00 781
# 36    04:17.25 12,00 751
# Name: Pts. IT, dtype: object

# %%
#Separando as colunas e renomeando as novas colunas
tabela1[[0, 1, 2]] = tabela1["Pts. IT"].str.split(" ", expand=True)
display(tabela1)
# Out:
# 5  Col. S                                 R Nome Patrocínio    Reg.  \
# 8    1° 1  4 GABRIELLE GONÇALVES RONCATTO MARINHA DO BRASIL  119052
# 12   2° 1     5 NATHALIA SIQUEIRA ALMEIDA MARINHA DO BRASIL  091438
# 16   3° 1                            3 MARIA PAULA HEITMANN  102920
# 20   4° 1            7 ALINE DA SILVA RODRIGUES AERONÁUTICA  084981
# 24   5° 1                        8 BEATRIZ PIMENTEL DIZOTTI  126635
# 28   6° 1                            2 SOFIA GARUFFI RONDEL  270127
# 32   7° 1                           6 GIOVANA REIS MEDEIROS  299900
# 36   8° 1                            1 GIULIA SALESI CHICON  250865
#
# 5        C. Nasc. Entidade             Pts. IT         0      1    2
# 8      1998 CR FLAMENGO/RJ  04:04.35 35,00 877  04:04.35  35,00  877
# 12     1996 CR FLAMENGO/RJ  04:04.66 30,00 874  04:04.66  30,00  874
# 16  1999 MINAS TENIS CLUBE  04:07.50 25,00 844  04:07.50  25,00  844
# 20  1995 MINAS TENIS CLUBE  04:12.25 20,00 797  04:12.25  20,00  797
# ...

# %%
# Retirando a coluna ["Pts. IT"] e Renomeando as novas colunas 0,1 e 2
tabela1.rename(columns={0: 'tempo'}, inplace=True)
tabela1.rename(columns={1: 'pontos'}, inplace=True)
tabela1.rename(columns={2: 'it'}, inplace=True)
tabela1 = tabela1.drop("Pts. IT", axis=1)
display(tabela1)
# Out:
# 5  Col. S                                 R Nome Patrocínio    Reg.  \
# 8    1° 1  4 GABRIELLE GONÇALVES RONCATTO MARINHA DO BRASIL  119052
# 12   2° 1     5 NATHALIA SIQUEIRA ALMEIDA MARINHA DO BRASIL  091438
# 16   3° 1                            3 MARIA PAULA HEITMANN  102920
# 20   4° 1            7 ALINE DA SILVA RODRIGUES AERONÁUTICA  084981
# 24   5° 1                        8 BEATRIZ PIMENTEL DIZOTTI  126635
# 28   6° 1                            2 SOFIA GARUFFI RONDEL  270127
# 32   7° 1                           6 GIOVANA REIS MEDEIROS  299900
# 36   8° 1                            1 GIULIA SALESI CHICON  250865
#
# 5        C. Nasc. Entidade     tempo pontos   it
# 8      1998 CR FLAMENGO/RJ  04:04.35  35,00  877
# 12     1996 CR FLAMENGO/RJ  04:04.66  30,00  874
# 16  1999 MINAS TENIS CLUBE  04:07.50  25,00  844
# 20  1995 MINAS TENIS CLUBE  04:12.25  20,00  797
# 24  2000 MINAS TENIS CLUBE  04:13.10  18,00  789
# 28        2002 CORINTHIANS  04:13.46  16,00  786
# ...

# %%
tabela1['C. Nasc. Entidade']
# Out:
# 8        1998 CR FLAMENGO/RJ
# 12       1996 CR FLAMENGO/RJ
# 16    1999 MINAS TENIS CLUBE
# 20    1995 MINAS TENIS CLUBE
# 24    2000 MINAS TENIS CLUBE
# 28          2002 CORINTHIANS
# 32            2004 PINHEIROS
# 36          2002 CORINTHIANS
# Name: C. Nasc. Entidade, dtype: object

# %%
#Separando as colunas e renomeando as novas colunas
tabela1[[0,1,2,3]] = tabela1["C. Nasc. Entidade"].str.split(" ", expand=True)
display(tabela1)
# Out:
# 5  Col. S                                 R Nome Patrocínio    Reg.  \
# 8    1° 1  4 GABRIELLE GONÇALVES RONCATTO MARINHA DO BRASIL  119052
# 12   2° 1     5 NATHALIA SIQUEIRA ALMEIDA MARINHA DO BRASIL  091438
# 16   3° 1                            3 MARIA PAULA HEITMANN  102920
# 20   4° 1            7 ALINE DA SILVA RODRIGUES AERONÁUTICA  084981
# 24   5° 1                        8 BEATRIZ PIMENTEL DIZOTTI  126635
# 28   6° 1                            2 SOFIA GARUFFI RONDEL  270127
# 32   7° 1                           6 GIOVANA REIS MEDEIROS  299900
# 36   8° 1                            1 GIULIA SALESI CHICON  250865
#
# 5        C. Nasc. Entidade     tempo pontos   it     0            1  \
# 8      1998 CR FLAMENGO/RJ  04:04.35  35,00  877  1998           CR
# 12     1996 CR FLAMENGO/RJ  04:04.66  30,00  874  1996           CR
# 16  1999 MINAS TENIS CLUBE  04:07.50  25,00  844  1999        MINAS
# 20  1995 MINAS TENIS CLUBE  04:12.25  20,00  797  1995        MINAS
# ...

# %%
# Retirando a coluna ["C. Nasc. Entidade"] e Renomeando as novas colunas 0,1,2 e 3
#Acertar nome CR para FlamengoRJ
tabela1.rename(columns={0: 'anoNasc'}, inplace=True)
tabela1.rename(columns={1: 'equipe'}, inplace=True)
tabela1.rename(columns={2: 'retirar1'}, inplace=True)
tabela1.rename(columns={3: 'retirar2'}, inplace=True)
tabela1 = tabela1.drop("C. Nasc. Entidade", axis=1)
display(tabela1)
#Col.= colocacao
#S = saida
#R = raia
#Nome=atleta
#Patrocinio=patrocinio
#Reg. C.= registro_conf
#Nasc.=ano_nascimento
#Entidade=equipe
#Tempo Obtido=tempo 
#Pts.=pontos
#IT
# Out:
# 5  Col. S                                 R Nome Patrocínio    Reg.     tempo  \
# 8    1° 1  4 GABRIELLE GONÇALVES RONCATTO MARINHA DO BRASIL  119052  04:04.35
# 12   2° 1     5 NATHALIA SIQUEIRA ALMEIDA MARINHA DO BRASIL  091438  04:04.66
# 16   3° 1                            3 MARIA PAULA HEITMANN  102920  04:07.50
# 20   4° 1            7 ALINE DA SILVA RODRIGUES AERONÁUTICA  084981  04:12.25
# 24   5° 1                        8 BEATRIZ PIMENTEL DIZOTTI  126635  04:13.10
# 28   6° 1                            2 SOFIA GARUFFI RONDEL  270127  04:13.46
# 32   7° 1                           6 GIOVANA REIS MEDEIROS  299900  04:14.00
# 36   8° 1                            1 GIULIA SALESI CHICON  250865  04:17.25
#
# 5  pontos   it anoNasc       equipe     retirar1 retirar2
# 8   35,00  877    1998           CR  FLAMENGO/RJ     None
# 12  30,00  874    1996           CR  FLAMENGO/RJ     None
# 16  25,00  844    1999        MINAS        TENIS    CLUBE
# ...

# %%
#Substituição de valores atraves do replace
tabela1['equipe'].replace(['CR','MINAS'],['FLAMENGO_RJ','MINAS_TENIS_CLUBE'], inplace=True)
display(tabela1.equipe)
# Out:
# 8           FLAMENGO_RJ
# 12          FLAMENGO_RJ
# 16    MINAS_TENIS_CLUBE
# 20    MINAS_TENIS_CLUBE
# 24    MINAS_TENIS_CLUBE
# 28          CORINTHIANS
# 32            PINHEIROS
# 36          CORINTHIANS
# Name: equipe, dtype: object

# %%
display(tabela1)
# Out:
# 5  Col. S                                 R Nome Patrocínio    Reg.     tempo  \
# 8    1° 1  4 GABRIELLE GONÇALVES RONCATTO MARINHA DO BRASIL  119052  04:04.35
# 12   2° 1     5 NATHALIA SIQUEIRA ALMEIDA MARINHA DO BRASIL  091438  04:04.66
# 16   3° 1                            3 MARIA PAULA HEITMANN  102920  04:07.50
# 20   4° 1            7 ALINE DA SILVA RODRIGUES AERONÁUTICA  084981  04:12.25
# 24   5° 1                        8 BEATRIZ PIMENTEL DIZOTTI  126635  04:13.10
# 28   6° 1                            2 SOFIA GARUFFI RONDEL  270127  04:13.46
# 32   7° 1                           6 GIOVANA REIS MEDEIROS  299900  04:14.00
# 36   8° 1                            1 GIULIA SALESI CHICON  250865  04:17.25
#
# 5  pontos   it anoNasc             equipe     retirar1 retirar2
# 8   35,00  877    1998        FLAMENGO_RJ  FLAMENGO/RJ     None
# 12  30,00  874    1996        FLAMENGO_RJ  FLAMENGO/RJ     None
# 16  25,00  844    1999  MINAS_TENIS_CLUBE        TENIS    CLUBE
# ...

# %%
#Retirando as colunas retirar1 e retirar2
tabela1 = tabela1.drop("retirar1", axis=1)
tabela1 = tabela1.drop("retirar2", axis=1)
display(tabela1)
# Out:
# 5  Col. S                                 R Nome Patrocínio    Reg.     tempo  \
# 8    1° 1  4 GABRIELLE GONÇALVES RONCATTO MARINHA DO BRASIL  119052  04:04.35
# 12   2° 1     5 NATHALIA SIQUEIRA ALMEIDA MARINHA DO BRASIL  091438  04:04.66
# 16   3° 1                            3 MARIA PAULA HEITMANN  102920  04:07.50
# 20   4° 1            7 ALINE DA SILVA RODRIGUES AERONÁUTICA  084981  04:12.25
# 24   5° 1                        8 BEATRIZ PIMENTEL DIZOTTI  126635  04:13.10
# 28   6° 1                            2 SOFIA GARUFFI RONDEL  270127  04:13.46
# 32   7° 1                           6 GIOVANA REIS MEDEIROS  299900  04:14.00
# 36   8° 1                            1 GIULIA SALESI CHICON  250865  04:17.25
#
# 5  pontos   it anoNasc             equipe
# 8   35,00  877    1998        FLAMENGO_RJ
# 12  30,00  874    1996        FLAMENGO_RJ
# 16  25,00  844    1999  MINAS_TENIS_CLUBE
# 20  20,00  797    1995  MINAS_TENIS_CLUBE
# 24  18,00  789    2000  MINAS_TENIS_CLUBE
# ...

# %%
tabela1['R Nome Patrocínio']
# Out:
# 8     4 GABRIELLE GONÇALVES RONCATTO MARINHA DO BRASIL
# 12       5 NATHALIA SIQUEIRA ALMEIDA MARINHA DO BRASIL
# 16                              3 MARIA PAULA HEITMANN
# 20              7 ALINE DA SILVA RODRIGUES AERONÁUTICA
# 24                          8 BEATRIZ PIMENTEL DIZOTTI
# 28                              2 SOFIA GARUFFI RONDEL
# 32                             6 GIOVANA REIS MEDEIROS
# 36                              1 GIULIA SALESI CHICON
# Name: R Nome Patrocínio, dtype: object

# %%
#Separando as colunas e renomeando as novas colunas
tabela1[[0,1,2,3,4,5,6]] = tabela1["R Nome Patrocínio"].str.split(" ", expand=True)
display(tabela1)
# Out:
# 5  Col. S                                 R Nome Patrocínio    Reg.     tempo  \
# 8    1° 1  4 GABRIELLE GONÇALVES RONCATTO MARINHA DO BRASIL  119052  04:04.35
# 12   2° 1     5 NATHALIA SIQUEIRA ALMEIDA MARINHA DO BRASIL  091438  04:04.66
# 16   3° 1                            3 MARIA PAULA HEITMANN  102920  04:07.50
# 20   4° 1            7 ALINE DA SILVA RODRIGUES AERONÁUTICA  084981  04:12.25
# 24   5° 1                        8 BEATRIZ PIMENTEL DIZOTTI  126635  04:13.10
# 28   6° 1                            2 SOFIA GARUFFI RONDEL  270127  04:13.46
# 32   7° 1                           6 GIOVANA REIS MEDEIROS  299900  04:14.00
# 36   8° 1                            1 GIULIA SALESI CHICON  250865  04:17.25
#
# 5  pontos   it anoNasc             equipe  0          1          2         3  \
# 8   35,00  877    1998        FLAMENGO_RJ  4  GABRIELLE  GONÇALVES  RONCATTO
# 12  30,00  874    1996        FLAMENGO_RJ  5   NATHALIA   SIQUEIRA   ALMEIDA
# ...

# %%
# Renomear as colunas
tabela1.rename(columns={0: 'raia'}, inplace=True)
tabela1.rename(columns={1: 'nome'}, inplace=True)
tabela1.rename(columns={3: 'sobrenome'}, inplace=True)
tabela1.rename(columns={4: 'patrocinio'}, inplace=True)

# Excluir a coluna R Nome Patrocínio
# Excluir a coluna 2
tabela1 = tabela1.drop("R Nome Patrocínio", axis=1)
tabela1 = tabela1.drop(2, axis=1)
tabela1 = tabela1.drop(6, axis=1)

#Substituo os valores  ALINE DA SILVA RODRIGUES de SILVA para S_RODRIGUES - Coluna 3
#Substituo os valores  ALINE DA SILVA RODRIGUES de RODRIGUES para AERONAUITCA - Coluna4
#Substituição de valores atraves do replace
tabela1['sobrenome'].replace(['SILVA'],['S_RODRIGUES'], inplace=True)
tabela1['patrocinio'].replace(['RODRIGUES'],['AERONÁUTICA'], inplace=True)

#Excluindo a coluna 5
tabela1 = tabela1.drop(5, axis=1)

#Mostrando a tabela
display(tabela1)
# Out:
# 5  Col. S    Reg.     tempo pontos   it anoNasc             equipe raia  \
# 8    1° 1  119052  04:04.35  35,00  877    1998        FLAMENGO_RJ    4
# 12   2° 1  091438  04:04.66  30,00  874    1996        FLAMENGO_RJ    5
# 16   3° 1  102920  04:07.50  25,00  844    1999  MINAS_TENIS_CLUBE    3
# 20   4° 1  084981  04:12.25  20,00  797    1995  MINAS_TENIS_CLUBE    7
# 24   5° 1  126635  04:13.10  18,00  789    2000  MINAS_TENIS_CLUBE    8
# 28   6° 1  270127  04:13.46  16,00  786    2002        CORINTHIANS    2
# 32   7° 1  299900  04:14.00  14,00  781    2004          PINHEIROS    6
# 36   8° 1  250865  04:17.25  12,00  751    2002        CORINTHIANS    1
#
# 5        nome    sobrenome   patrocinio
# 8   GABRIELLE     RONCATTO      MARINHA
# 12   NATHALIA      ALMEIDA      MARINHA
# 16      MARIA     HEITMANN         None
# 20      ALINE  S_RODRIGUES  AERONÁUTICA
# 24    BEATRIZ      DIZOTTI         None
# 28      SOFIA       RONDEL         None
# ...

# %%
#Separando as colunas e renomeando as novas colunas
tabela1[[0,1]] = tabela1["Col. S"].str.split(" ", expand=True)
#Renomeando as colunas
tabela1.rename(columns={0: 'colocacao'}, inplace=True)
tabela1.rename(columns={1: 'bateria'}, inplace=True)


#Excluindo a coluna Col. S 
tabela1 = tabela1.drop("Col. S", axis=1)

display(tabela1)
# Out:
# 5     Reg.     tempo pontos   it anoNasc             equipe raia       nome  \
# 8   119052  04:04.35  35,00  877    1998        FLAMENGO_RJ    4  GABRIELLE
# 12  091438  04:04.66  30,00  874    1996        FLAMENGO_RJ    5   NATHALIA
# 16  102920  04:07.50  25,00  844    1999  MINAS_TENIS_CLUBE    3      MARIA
# 20  084981  04:12.25  20,00  797    1995  MINAS_TENIS_CLUBE    7      ALINE
# 24  126635  04:13.10  18,00  789    2000  MINAS_TENIS_CLUBE    8    BEATRIZ
# 28  270127  04:13.46  16,00  786    2002        CORINTHIANS    2      SOFIA
# 32  299900  04:14.00  14,00  781    2004          PINHEIROS    6    GIOVANA
# 36  250865  04:17.25  12,00  751    2002        CORINTHIANS    1     GIULIA
#
# 5     sobrenome   patrocinio colocacao bateria
# 8      RONCATTO      MARINHA        1°       1
# 12      ALMEIDA      MARINHA        2°       1
# 16     HEITMANN         None        3°       1
# 20  S_RODRIGUES  AERONÁUTICA        4°       1
# ...

# %% [markdown]
# ### Tabela1- Bateria1

# %%
#Reorganizando as colunas:
tabela1=tabela1[['bateria','colocacao','nome','sobrenome','patrocinio','Reg.','anoNasc','equipe','tempo','pontos','it']]

#Alterando o indice da minha tabela para a colocacao
#tabela1=tabela1.set_index("colocacao")

display(tabela1)
# Out:
# 5  bateria colocacao       nome    sobrenome   patrocinio    Reg. anoNasc  \
# 8        1        1°  GABRIELLE     RONCATTO      MARINHA  119052    1998
# 12       1        2°   NATHALIA      ALMEIDA      MARINHA  091438    1996
# 16       1        3°      MARIA     HEITMANN         None  102920    1999
# 20       1        4°      ALINE  S_RODRIGUES  AERONÁUTICA  084981    1995
# 24       1        5°    BEATRIZ      DIZOTTI         None  126635    2000
# 28       1        6°      SOFIA       RONDEL         None  270127    2002
# 32       1        7°    GIOVANA     MEDEIROS         None  299900    2004
# 36       1        8°     GIULIA       CHICON         None  250865    2002
#
# 5              equipe     tempo pontos   it
# 8         FLAMENGO_RJ  04:04.35  35,00  877
# 12        FLAMENGO_RJ  04:04.66  30,00  874
# 16  MINAS_TENIS_CLUBE  04:07.50  25,00  844
# 20  MINAS_TENIS_CLUBE  04:12.25  20,00  797
# 24  MINAS_TENIS_CLUBE  04:13.10  18,00  789
# ...

# %% [markdown]
# ## Trabalhando com o tempo das atletas - bateria 1

# %% [markdown]
# ### Tabela2 - Tempos das atletas - bateria 1

# %% [markdown]
# ## Análise Exploratoria

# %%
# importando as bibliotecas
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
#pd.options.plotting.backend = "plotly"

from matplotlib.ticker import FuncFormatter

# Datetime
from datetime import datetime

# Informar ao matplotlib sobre os gráficos inline
# %matplotlib inline

df_tabela2 = pd.read_excel('drive/MyDrive/Colab Notebooks/Natação_Dados/tempos.xlsx',sheet_name='Folha3')

# %%
display(df_tabela2)
# Out:
#       medidas                         raia4                      raia5  \
# 0           0                      00:00.00                   00:00.00
# 1          25                      00:28.29                   00:28.30
# 2          50                     00:42.76                    00:43:41
# 3          75                     00:57.86                   00:58.85
# 4         100                      01:13.01                   01:13.98
# 5         125                      01:28.38                   01:29.45
# 6         150                      01:43.87                  01:44.80
# 7         175                      01:59.61                   02:00.54
# 8         200                      02:15.23                   02:15.81
# 9         225                      02:31.02                   02:31.49
# 10        250                     02:46.59                    02:46.98
# 11        275                      03:02.43                  03:02.72
# ...

# %%
df_tabela2=df_tabela2[0:16]
df_tabela2
# Out:
#    medidas      raia4      raia5       raia3      raia7       raia8  \
# 0        0   00:00.00   00:00.00    00:00.00   00:00.00    00:00.00
# 1       25   00:28.29   00:28.30   00:29.29   00:28.93     00:29.46
# 2       50  00:42.76    00:43:41    00:44.55   00:44.40   00:45.15
# 3       75  00:57.86   00:58.85    01:00.05    01:00.10    01:01.10
# 4      100   01:13.01   01:13.98   01:15.51    01:15.59    01:17.07
# 5      125   01:28.38   01:29.45   01:31.08    01:31.16   01:33.34
# 6      150   01:43.87  01:44.80     01:46.58   01:46.85   01:49.42
# 7      175   01:59.61   02:00.54    02:02.21   02:02.78   02:05.48
# 8      200   02:15.23   02:15.81    02:17.72   02:18.74    02:21.59
# 9      225   02:31.02   02:31.49   02:33.41    02:34.82    02:37.78
# 10     250  02:46.59    02:46.98   02:49.04    02:51.15    02:53.86
# 11     275   03:02.43  03:02.72     03:04.79   03:07.41    03:10.01
# 12     300   03:18.10   03:18.22    03:20.37   03:23.69   03:26.03
# ...

# %%
df_tabela2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   medidas  16 non-null     object
#  1   raia4    16 non-null     object
#  2   raia5    16 non-null     object
#  3   raia3    16 non-null     object
#  4   raia7    16 non-null     object
#  5   raia8    16 non-null     object
#  6   raia2    16 non-null     object
#  7   raia6    16 non-null     object
#  8   raia1    16 non-null     object
# dtypes: object(9)
# memory usage: 1.2+ KB

# %%
#df_tabela2=df_tabela2.apply(lambda x: str(x).replace(".",":"))

# %%
df_tabela2
# Out:
#    medidas      raia4      raia5       raia3      raia7       raia8  \
# 0        0   00:00.00   00:00.00    00:00.00   00:00.00    00:00.00
# 1       25   00:28.29   00:28.30   00:29.29   00:28.93     00:29.46
# 2       50  00:42.76    00:43:41    00:44.55   00:44.40   00:45.15
# 3       75  00:57.86   00:58.85    01:00.05    01:00.10    01:01.10
# 4      100   01:13.01   01:13.98   01:15.51    01:15.59    01:17.07
# 5      125   01:28.38   01:29.45   01:31.08    01:31.16   01:33.34
# 6      150   01:43.87  01:44.80     01:46.58   01:46.85   01:49.42
# 7      175   01:59.61   02:00.54    02:02.21   02:02.78   02:05.48
# 8      200   02:15.23   02:15.81    02:17.72   02:18.74    02:21.59
# 9      225   02:31.02   02:31.49   02:33.41    02:34.82    02:37.78
# 10     250  02:46.59    02:46.98   02:49.04    02:51.15    02:53.86
# 11     275   03:02.43  03:02.72     03:04.79   03:07.41    03:10.01
# 12     300   03:18.10   03:18.22    03:20.37   03:23.69   03:26.03
# ...

# %%
a= df_tabela2['raia4'].values
a
# Out:
# array(['00:00.00', '00:28.29', '00:42.76 ', '00:57.86 ', ' 01:13.01',
#        '01:28.38', '01:43.87', '01:59.61', ' 02:15.23', '02:31.02',
#        '02:46.59 ', '03:02.43', '03:18.10', '03:33.96 ', '03:49.58',
#        '04:04.35'], dtype=object)

# %%
df_tabela2.shape
# Out:
# (16, 9)

# %%
#df_tabela2[4].values

# %%
#Formatando os dados - verificar os espaços
r4= pd.Series(['00:00.00', '00:28.29', '00:42.76', '00:57.86', '01:13.01',
       '01:28.38', '01:43.87', '01:59.61', '02:15.23', '02:31.02',
       '02:46.59', '03:02.43', '03:18.10', '03:33.96', '03:49.58',
       '04:04.35'])
r4
# Out:
# 0     00:00.00
# 1     00:28.29
# 2     00:42.76
# 3     00:57.86
# 4     01:13.01
# 5     01:28.38
# 6     01:43.87
# 7     01:59.61
# 8     02:15.23
# 9     02:31.02
# 10    02:46.59
# 11    03:02.43
# 12    03:18.10
# 13    03:33.96
# 14    03:49.58
# 15    04:04.35
# dtype: object

# %% [markdown]
# ### Formatação de datas
