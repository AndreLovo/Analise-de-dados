# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreLovo/Analise-de-dados/blob/master/C%C3%B3pia_de_Energia_Ren_USA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **<center>ENERGIA RENOVÁVEL USA</center>**
#
# <center> Análise Exploratória </center>

# %%
# Tabela Energia Renovável USA
 
# Importando as dependencias do Seaborn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_energia = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Energia_Renovavel/datasets_82851_192539_Net_generation_for_all_sectors.csv')
df_energia
# Out:
#                                     description                   units  \
# 0                Net generation for all sectors  thousand megawatthours
# 1                                 United States                     NaN
# 2     United States : all fuels (utility-scale)                     NaN
# 3              United States : other renewables  thousand megawatthours
# 4                          United States : wind  thousand megawatthours
# 5       United States : all utility-scale solar  thousand megawatthours
# 6                    United States : geothermal  thousand megawatthours
# 7                       United States : biomass                     NaN
# 8   United States : wood and wood-derived fuels  thousand megawatthours
# 9                 United States : other biomass  thousand megawatthours
# 10      United States : all utility-scale solar  thousand megawatthours
#
#               source key  Jan 2001  Feb 2001  Mar 2001  Apr 2001  May 2001  \
# 0                    NaN       NaN       NaN       NaN       NaN       NaN
# 1            ELEC.GEN..M       NaN       NaN       NaN       NaN       NaN
# 2   ELEC.GEN.ALL-US-99.M       NaN       NaN       NaN       NaN       NaN
# 3   ELEC.GEN.AOR-US-99.M    6025.0    5310.0    5795.0    5827.0    5738.0
# 4   ELEC.GEN.WND-US-99.M     389.0     431.0     532.0     685.0     635.0
# 5   ELEC.GEN.SUN-US-99.M       7.0      13.0      31.0      39.0      81.0
# 6   ELEC.GEN.GEO-US-99.M    1229.0    1073.0    1190.0    1095.0    1071.0
# 7   ELEC.GEN.BIO-US-99.M       NaN       NaN       NaN       NaN       NaN
# 8   ELEC.GEN.WWW-US-99.M    3191.0    2697.0    2853.0    2821.0    2740.0
# 9   ELEC.GEN.WAS-US-99.M    1209.0    1096.0    1189.0    1187.0    1211.0
# 10  ELEC.GEN.SUN-US-99.M       7.0      13.0      31.0      39.0      81.0
#
#     Jun 2001  Jul 2001  ...  Feb 2016  Mar 2016  Apr 2016  May 2016  Jun 2016  \
# 0        NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 1        NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 3     5964.0    6244.0  ...   28738.0   31084.0   29666.0   28711.0   26236.0
# 4      670.0     635.0  ...   20138.0   21939.0   20799.0   18848.0   16303.0
# 5       91.0      92.0  ...    2242.0    2617.0    2880.0    3425.0    3473.0
# 6     1088.0    1179.0  ...    1243.0    1315.0    1209.0    1342.0    1251.0
# 7        NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 8     2891.0    3053.0  ...    3406.0    3403.0    2967.0    3187.0    3414.0
# 9     1225.0    1286.0  ...    1708.0    1809.0    1811.0    1909.0    1794.0
# 10      91.0      92.0  ...    2242.0    2617.0    2880.0    3425.0    3473.0
#
#     Jul 2016  Aug 2016  Sep 2016  Oct 2016  Nov 2016
# 0        NaN       NaN       NaN       NaN       NaN
# 1        NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN       NaN
# 3    28372.0   24465.0   26529.0   29749.0   28819.0
# 4    17618.0   13589.0   16404.0   20335.0   19406.0
# 5     3945.0    3969.0    3635.0    3191.0    2767.0
# 6     1311.0    1324.0    1327.0    1353.0    1364.0
# 7        NaN       NaN       NaN       NaN       NaN
# 8     3658.0    3722.0    3407.0    3176.0    3391.0
# 9     1840.0    1860.0    1757.0    1693.0    1891.0
# 10    3945.0    3969.0    3635.0    3191.0    2767.0
#
# [11 rows x 194 columns]

# %%
# Excluindo a coluna sorce Key # inplace = a mudança é realizada definitiva - axis = 1 retiro a coluna 
df_energia.drop('source key', axis=1, inplace=False)
df_energia
# Out:
#                                     description                   units  \
# 0                Net generation for all sectors  thousand megawatthours
# 1                                 United States                     NaN
# 2     United States : all fuels (utility-scale)                     NaN
# 3              United States : other renewables  thousand megawatthours
# 4                          United States : wind  thousand megawatthours
# 5       United States : all utility-scale solar  thousand megawatthours
# 6                    United States : geothermal  thousand megawatthours
# 7                       United States : biomass                     NaN
# 8   United States : wood and wood-derived fuels  thousand megawatthours
# 9                 United States : other biomass  thousand megawatthours
# 10      United States : all utility-scale solar  thousand megawatthours
#
#               source key  Jan 2001  Feb 2001  Mar 2001  Apr 2001  May 2001  \
# 0                    NaN       NaN       NaN       NaN       NaN       NaN
# 1            ELEC.GEN..M       NaN       NaN       NaN       NaN       NaN
# 2   ELEC.GEN.ALL-US-99.M       NaN       NaN       NaN       NaN       NaN
# 3   ELEC.GEN.AOR-US-99.M    6025.0    5310.0    5795.0    5827.0    5738.0
# 4   ELEC.GEN.WND-US-99.M     389.0     431.0     532.0     685.0     635.0
# 5   ELEC.GEN.SUN-US-99.M       7.0      13.0      31.0      39.0      81.0
# 6   ELEC.GEN.GEO-US-99.M    1229.0    1073.0    1190.0    1095.0    1071.0
# 7   ELEC.GEN.BIO-US-99.M       NaN       NaN       NaN       NaN       NaN
# 8   ELEC.GEN.WWW-US-99.M    3191.0    2697.0    2853.0    2821.0    2740.0
# 9   ELEC.GEN.WAS-US-99.M    1209.0    1096.0    1189.0    1187.0    1211.0
# 10  ELEC.GEN.SUN-US-99.M       7.0      13.0      31.0      39.0      81.0
#
#     Jun 2001  Jul 2001  ...  Feb 2016  Mar 2016  Apr 2016  May 2016  Jun 2016  \
# 0        NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 1        NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 3     5964.0    6244.0  ...   28738.0   31084.0   29666.0   28711.0   26236.0
# 4      670.0     635.0  ...   20138.0   21939.0   20799.0   18848.0   16303.0
# 5       91.0      92.0  ...    2242.0    2617.0    2880.0    3425.0    3473.0
# 6     1088.0    1179.0  ...    1243.0    1315.0    1209.0    1342.0    1251.0
# 7        NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 8     2891.0    3053.0  ...    3406.0    3403.0    2967.0    3187.0    3414.0
# 9     1225.0    1286.0  ...    1708.0    1809.0    1811.0    1909.0    1794.0
# 10      91.0      92.0  ...    2242.0    2617.0    2880.0    3425.0    3473.0
#
#     Jul 2016  Aug 2016  Sep 2016  Oct 2016  Nov 2016
# 0        NaN       NaN       NaN       NaN       NaN
# 1        NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN       NaN
# 3    28372.0   24465.0   26529.0   29749.0   28819.0
# 4    17618.0   13589.0   16404.0   20335.0   19406.0
# 5     3945.0    3969.0    3635.0    3191.0    2767.0
# 6     1311.0    1324.0    1327.0    1353.0    1364.0
# 7        NaN       NaN       NaN       NaN       NaN
# 8     3658.0    3722.0    3407.0    3176.0    3391.0
# 9     1840.0    1860.0    1757.0    1693.0    1891.0
# 10    3945.0    3969.0    3635.0    3191.0    2767.0
#
# [11 rows x 194 columns]

# %%
# Excluindo as linhas indices 1 e 2 
df_energia.drop(1, axis=0, inplace=True) # inplace = a mudança é realizada - axis=0 retiro a linha - 
df_energia.drop(2, axis=0, inplace=True)

df_energia
# Out:
#                                     description                   units  \
# 0                Net generation for all sectors  thousand megawatthours
# 3              United States : other renewables  thousand megawatthours
# 4                          United States : wind  thousand megawatthours
# 5       United States : all utility-scale solar  thousand megawatthours
# 6                    United States : geothermal  thousand megawatthours
# 7                       United States : biomass                     NaN
# 8   United States : wood and wood-derived fuels  thousand megawatthours
# 9                 United States : other biomass  thousand megawatthours
# 10      United States : all utility-scale solar  thousand megawatthours
#
#               source key  Jan 2001  Feb 2001  Mar 2001  Apr 2001  May 2001  \
# 0                    NaN       NaN       NaN       NaN       NaN       NaN
# 3   ELEC.GEN.AOR-US-99.M    6025.0    5310.0    5795.0    5827.0    5738.0
# 4   ELEC.GEN.WND-US-99.M     389.0     431.0     532.0     685.0     635.0
# 5   ELEC.GEN.SUN-US-99.M       7.0      13.0      31.0      39.0      81.0
# 6   ELEC.GEN.GEO-US-99.M    1229.0    1073.0    1190.0    1095.0    1071.0
# 7   ELEC.GEN.BIO-US-99.M       NaN       NaN       NaN       NaN       NaN
# 8   ELEC.GEN.WWW-US-99.M    3191.0    2697.0    2853.0    2821.0    2740.0
# 9   ELEC.GEN.WAS-US-99.M    1209.0    1096.0    1189.0    1187.0    1211.0
# 10  ELEC.GEN.SUN-US-99.M       7.0      13.0      31.0      39.0      81.0
#
#     Jun 2001  Jul 2001  ...  Feb 2016  Mar 2016  Apr 2016  May 2016  Jun 2016  \
# 0        NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 3     5964.0    6244.0  ...   28738.0   31084.0   29666.0   28711.0   26236.0
# 4      670.0     635.0  ...   20138.0   21939.0   20799.0   18848.0   16303.0
# 5       91.0      92.0  ...    2242.0    2617.0    2880.0    3425.0    3473.0
# 6     1088.0    1179.0  ...    1243.0    1315.0    1209.0    1342.0    1251.0
# 7        NaN       NaN  ...       NaN       NaN       NaN       NaN       NaN
# 8     2891.0    3053.0  ...    3406.0    3403.0    2967.0    3187.0    3414.0
# 9     1225.0    1286.0  ...    1708.0    1809.0    1811.0    1909.0    1794.0
# 10      91.0      92.0  ...    2242.0    2617.0    2880.0    3425.0    3473.0
#
#     Jul 2016  Aug 2016  Sep 2016  Oct 2016  Nov 2016
# 0        NaN       NaN       NaN       NaN       NaN
# 3    28372.0   24465.0   26529.0   29749.0   28819.0
# 4    17618.0   13589.0   16404.0   20335.0   19406.0
# 5     3945.0    3969.0    3635.0    3191.0    2767.0
# 6     1311.0    1324.0    1327.0    1353.0    1364.0
# 7        NaN       NaN       NaN       NaN       NaN
# 8     3658.0    3722.0    3407.0    3176.0    3391.0
# 9     1840.0    1860.0    1757.0    1693.0    1891.0
# 10    3945.0    3969.0    3635.0    3191.0    2767.0
#
# [9 rows x 194 columns]

# %%
# Retirando todos os valores NaN - preciso criar outro DataFrame para 
# receber a nova tabela
df_energia1 = df_energia.dropna()
df_energia1
# Out:
#                                     description                   units  \
# 3              United States : other renewables  thousand megawatthours
# 4                          United States : wind  thousand megawatthours
# 5       United States : all utility-scale solar  thousand megawatthours
# 6                    United States : geothermal  thousand megawatthours
# 8   United States : wood and wood-derived fuels  thousand megawatthours
# 9                 United States : other biomass  thousand megawatthours
# 10      United States : all utility-scale solar  thousand megawatthours
#
#               source key  Jan 2001  Feb 2001  Mar 2001  Apr 2001  May 2001  \
# 3   ELEC.GEN.AOR-US-99.M    6025.0    5310.0    5795.0    5827.0    5738.0
# 4   ELEC.GEN.WND-US-99.M     389.0     431.0     532.0     685.0     635.0
# 5   ELEC.GEN.SUN-US-99.M       7.0      13.0      31.0      39.0      81.0
# 6   ELEC.GEN.GEO-US-99.M    1229.0    1073.0    1190.0    1095.0    1071.0
# 8   ELEC.GEN.WWW-US-99.M    3191.0    2697.0    2853.0    2821.0    2740.0
# 9   ELEC.GEN.WAS-US-99.M    1209.0    1096.0    1189.0    1187.0    1211.0
# 10  ELEC.GEN.SUN-US-99.M       7.0      13.0      31.0      39.0      81.0
#
#     Jun 2001  Jul 2001  ...  Feb 2016  Mar 2016  Apr 2016  May 2016  Jun 2016  \
# 3     5964.0    6244.0  ...   28738.0   31084.0   29666.0   28711.0   26236.0
# 4      670.0     635.0  ...   20138.0   21939.0   20799.0   18848.0   16303.0
# 5       91.0      92.0  ...    2242.0    2617.0    2880.0    3425.0    3473.0
# 6     1088.0    1179.0  ...    1243.0    1315.0    1209.0    1342.0    1251.0
# 8     2891.0    3053.0  ...    3406.0    3403.0    2967.0    3187.0    3414.0
# 9     1225.0    1286.0  ...    1708.0    1809.0    1811.0    1909.0    1794.0
# 10      91.0      92.0  ...    2242.0    2617.0    2880.0    3425.0    3473.0
#
#     Jul 2016  Aug 2016  Sep 2016  Oct 2016  Nov 2016
# 3    28372.0   24465.0   26529.0   29749.0   28819.0
# 4    17618.0   13589.0   16404.0   20335.0   19406.0
# 5     3945.0    3969.0    3635.0    3191.0    2767.0
# 6     1311.0    1324.0    1327.0    1353.0    1364.0
# 8     3658.0    3722.0    3407.0    3176.0    3391.0
# 9     1840.0    1860.0    1757.0    1693.0    1891.0
# 10    3945.0    3969.0    3635.0    3191.0    2767.0
#
# [7 rows x 194 columns]

# %%
# Tombando a tabela para melhor visualização
df_energia2 = df_energia1.T
df_energia2
# Out:
#                                            3                       4   \
# description  United States : other renewables    United States : wind
# units                  thousand megawatthours  thousand megawatthours
# source key               ELEC.GEN.AOR-US-99.M    ELEC.GEN.WND-US-99.M
# Jan 2001                               6025.0                   389.0
# Feb 2001                               5310.0                   431.0
# ...                                       ...                     ...
# Jul 2016                              28372.0                 17618.0
# Aug 2016                              24465.0                 13589.0
# Sep 2016                              26529.0                 16404.0
# Oct 2016                              29749.0                 20335.0
# Nov 2016                              28819.0                 19406.0
#
#                                                   5   \
# description  United States : all utility-scale solar
# units                         thousand megawatthours
# source key                      ELEC.GEN.SUN-US-99.M
# Jan 2001                                         7.0
# Feb 2001                                        13.0
# ...                                              ...
# Jul 2016                                      3945.0
# Aug 2016                                      3969.0
# Sep 2016                                      3635.0
# Oct 2016                                      3191.0
# Nov 2016                                      2767.0
#
#                                      6   \
# description  United States : geothermal
# units            thousand megawatthours
# source key         ELEC.GEN.GEO-US-99.M
# Jan 2001                         1229.0
# Feb 2001                         1073.0
# ...                                 ...
# Jul 2016                         1311.0
# Aug 2016                         1324.0
# Sep 2016                         1327.0
# Oct 2016                         1353.0
# Nov 2016                         1364.0
#
#                                                       8   \
# description  United States : wood and wood-derived fuels
# units                             thousand megawatthours
# source key                          ELEC.GEN.WWW-US-99.M
# Jan 2001                                          3191.0
# Feb 2001                                          2697.0
# ...                                                  ...
# Jul 2016                                          3658.0
# Aug 2016                                          3722.0
# Sep 2016                                          3407.0
# Oct 2016                                          3176.0
# Nov 2016                                          3391.0
#
#                                         9   \
# description  United States : other biomass
# units               thousand megawatthours
# source key            ELEC.GEN.WAS-US-99.M
# Jan 2001                            1209.0
# Feb 2001                            1096.0
# ...                                    ...
# Jul 2016                            1840.0
# Aug 2016                            1860.0
# Sep 2016                            1757.0
# Oct 2016                            1693.0
# Nov 2016                            1891.0
#
#                                                   10
# description  United States : all utility-scale solar
# units                         thousand megawatthours
# source key                      ELEC.GEN.SUN-US-99.M
# Jan 2001                                         7.0
# Feb 2001                                        13.0
# ...                                              ...
# Jul 2016                                      3945.0
# Aug 2016                                      3969.0
# Sep 2016                                      3635.0
# Oct 2016                                      3191.0
# Nov 2016                                      2767.0
#
# [194 rows x 7 columns]

# %%
# Vamos analisar os tipos das colunas
df_energia2.info
# Out:
# <bound method DataFrame.info of                                            3                       4   \
# description  United States : other renewables    United States : wind
# units                  thousand megawatthours  thousand megawatthours
# source key               ELEC.GEN.AOR-US-99.M    ELEC.GEN.WND-US-99.M
# Jan 2001                               6025.0                   389.0
# Feb 2001                               5310.0                   431.0
# ...                                       ...                     ...
# Jul 2016                              28372.0                 17618.0
# Aug 2016                              24465.0                 13589.0
# Sep 2016                              26529.0                 16404.0
# Oct 2016                              29749.0                 20335.0
# Nov 2016                              28819.0                 19406.0
#
#                                                   5   \
# description  United States : all utility-scale solar
# units                         thousand megawatthours
# source key                      ELEC.GEN.SUN-US-99.M
# Jan 2001                                         7.0
# Feb 2001                                        13.0
# ...                                              ...
# Jul 2016                                      3945.0
# Aug 2016                                      3969.0
# Sep 2016                                      3635.0
# Oct 2016                                      3191.0
# Nov 2016                                      2767.0
#
#                                      6   \
# description  United States : geothermal
# units            thousand megawatthours
# source key         ELEC.GEN.GEO-US-99.M
# Jan 2001                         1229.0
# Feb 2001                         1073.0
# ...                                 ...
# Jul 2016                         1311.0
# Aug 2016                         1324.0
# Sep 2016                         1327.0
# Oct 2016                         1353.0
# Nov 2016                         1364.0
#
#                                                       8   \
# description  United States : wood and wood-derived fuels
# units                             thousand megawatthours
# source key                          ELEC.GEN.WWW-US-99.M
# Jan 2001                                          3191.0
# Feb 2001                                          2697.0
# ...                                                  ...
# Jul 2016                                          3658.0
# Aug 2016                                          3722.0
# Sep 2016                                          3407.0
# Oct 2016                                          3176.0
# Nov 2016                                          3391.0
#
#                                         9   \
# description  United States : other biomass
# units               thousand megawatthours
# source key            ELEC.GEN.WAS-US-99.M
# Jan 2001                            1209.0
# Feb 2001                            1096.0
# ...                                    ...
# Jul 2016                            1840.0
# Aug 2016                            1860.0
# Sep 2016                            1757.0
# Oct 2016                            1693.0
# Nov 2016                            1891.0
#
#                                                   10
# description  United States : all utility-scale solar
# units                         thousand megawatthours
# source key                      ELEC.GEN.SUN-US-99.M
# Jan 2001                                         7.0
# Feb 2001                                        13.0
# ...                                              ...
# Jul 2016                                      3945.0
# Aug 2016                                      3969.0
# Sep 2016                                      3635.0
# Oct 2016                                      3191.0
# Nov 2016                                      2767.0
#
# [194 rows x 7 columns]>

# %%
#Criando uma nova coluna com as datas - Inserindo nova coluna
nova_coluna = ['Data','','','Jan2001','Feb2001','Mar2001','Apr2001','May2001','Jun2001','Jul2001','Aug2001','Sep2001','Oct2001','Nov2001','Dec2001','Jan2002','Feb2002','Mar2002','Apr2002','May2002','Jun2002','Jul2002','Aug2002','Sep2002','Oct2002','Nov2002','Dec2002','Jan2003','Feb2003','Mar2003','Apr2003','May2003','Jun2003','Jul2003','Aug2003','Sep2003','Oct2003','Nov2003','Dec2003','Jan2004','Feb2004','Mar2004','Apr2004','May2004','Jun2004','Jul2004','Aug2004','Sep2004','Oct2004','Nov2004','Dec2004','Jan2005','Feb2005','Mar2005','Apr2005','May2005','Jun2005','Jul2005','Aug2005','Sep2005','Oct2005','Nov2005','Dec2005','Jan2006','Feb2006','Mar2006','Apr2006','May2006','Jun2006','Jul2006','Aug2006','Sep2006','Oct2006','Nov2006','Dec2006','Jan2007','Feb2007','Mar2007','Apr2007','May2007','Jun2007','Jul2007','Aug2007','Sep2007','Oct2007','Nov2007','Dec2007','Jan2008','Feb2008','Mar2008','Apr2008','May2008','Jun2008','Jul2008','Aug2008','Sep2008','Oct2008','Nov2008','Dec2008','Jan2009','Feb2009','Mar2009','Apr2009','May2009','Jun2009','Jul2009','Aug2009','Sep2009','Oct2009','Nov2009','Dec2009','Jan2010','Feb2010','Mar2010','Apr2010','May2010','Jun2010','Jul2010','Aug2010','Sep2010','Oct2010','Nov2010','Dec2010','Jan2011','Feb2011','Mar2011','Apr2011','May2011','Jun2011','Jul2011','Aug2011','Sep2011','Oct2011','Nov2011','Dec2011','Jan2012','Feb2012','Mar2012','Apr2012','May2012','Jun2012','Jul2012','Aug2012','Sep2012','Oct2012','Nov2012','Dec2012','Jan2013','Feb2013','Mar2013','Apr2013','May2013','Jun2013','Jul2013','Aug2013','Sep2013','Oct2013','Nov2013','Dec2013','Jan2014','Feb2014','Mar2014','Apr2014','May2014','Jun2014','Jul2014','Aug2014','Sep2014','Oct2014','Nov2014','Dec2014','Jan2015','Feb2015','Mar2015','Apr2015','May2015','Jun2015','Jul2015','Aug2015','Sep2015','Oct2015','Nov2015','Dec2015','Jan2016','Feb2016','Mar2016','Apr2016','May2016','Jun2016','Jul2016','Aug2016','Sep2016','Oct2016','Nov2016']

# %%
# Verificar os tamanhos e tipos dos dados
len(nova_coluna)
# Out:
# 194

# %%
# Selecionando as Colunas:
df_energia3 = df_energia2.iloc[:, 0:6]
df_energia3
# Out:
#                                             3                       4  \
# description  United States : other renewables    United States : wind
# units                  thousand megawatthours  thousand megawatthours
# source key               ELEC.GEN.AOR-US-99.M    ELEC.GEN.WND-US-99.M
# Jan 2001                               6025.0                   389.0
# Feb 2001                               5310.0                   431.0
# ...                                       ...                     ...
# Jul 2016                              28372.0                 17618.0
# Aug 2016                              24465.0                 13589.0
# Sep 2016                              26529.0                 16404.0
# Oct 2016                              29749.0                 20335.0
# Nov 2016                              28819.0                 19406.0
#
#                                                    5  \
# description  United States : all utility-scale solar
# units                         thousand megawatthours
# source key                      ELEC.GEN.SUN-US-99.M
# Jan 2001                                         7.0
# Feb 2001                                        13.0
# ...                                              ...
# Jul 2016                                      3945.0
# Aug 2016                                      3969.0
# Sep 2016                                      3635.0
# Oct 2016                                      3191.0
# Nov 2016                                      2767.0
#
#                                       6  \
# description  United States : geothermal
# units            thousand megawatthours
# source key         ELEC.GEN.GEO-US-99.M
# Jan 2001                         1229.0
# Feb 2001                         1073.0
# ...                                 ...
# Jul 2016                         1311.0
# Aug 2016                         1324.0
# Sep 2016                         1327.0
# Oct 2016                         1353.0
# Nov 2016                         1364.0
#
#                                                        8  \
# description  United States : wood and wood-derived fuels
# units                             thousand megawatthours
# source key                          ELEC.GEN.WWW-US-99.M
# Jan 2001                                          3191.0
# Feb 2001                                          2697.0
# ...                                                  ...
# Jul 2016                                          3658.0
# Aug 2016                                          3722.0
# Sep 2016                                          3407.0
# Oct 2016                                          3176.0
# Nov 2016                                          3391.0
#
#                                          9
# description  United States : other biomass
# units               thousand megawatthours
# source key            ELEC.GEN.WAS-US-99.M
# Jan 2001                            1209.0
# Feb 2001                            1096.0
# ...                                    ...
# Jul 2016                            1840.0
# Aug 2016                            1860.0
# Sep 2016                            1757.0
# Oct 2016                            1693.0
# Nov 2016                            1891.0
#
# [194 rows x 6 columns]

# %%
# Vamos analisar os tipos das colunas
df_energia3.info
# Out:
# <bound method DataFrame.info of                                             3                       4  \
# description  United States : other renewables    United States : wind
# units                  thousand megawatthours  thousand megawatthours
# source key               ELEC.GEN.AOR-US-99.M    ELEC.GEN.WND-US-99.M
# Jan 2001                               6025.0                   389.0
# Feb 2001                               5310.0                   431.0
# ...                                       ...                     ...
# Jul 2016                              28372.0                 17618.0
# Aug 2016                              24465.0                 13589.0
# Sep 2016                              26529.0                 16404.0
# Oct 2016                              29749.0                 20335.0
# Nov 2016                              28819.0                 19406.0
#
#                                                    5  \
# description  United States : all utility-scale solar
# units                         thousand megawatthours
# source key                      ELEC.GEN.SUN-US-99.M
# Jan 2001                                         7.0
# Feb 2001                                        13.0
# ...                                              ...
# Jul 2016                                      3945.0
# Aug 2016                                      3969.0
# Sep 2016                                      3635.0
# Oct 2016                                      3191.0
# Nov 2016                                      2767.0
#
#                                       6  \
# description  United States : geothermal
# units            thousand megawatthours
# source key         ELEC.GEN.GEO-US-99.M
# Jan 2001                         1229.0
# Feb 2001                         1073.0
# ...                                 ...
# Jul 2016                         1311.0
# Aug 2016                         1324.0
# Sep 2016                         1327.0
# Oct 2016                         1353.0
# Nov 2016                         1364.0
#
#                                                        8  \
# description  United States : wood and wood-derived fuels
# units                             thousand megawatthours
# source key                          ELEC.GEN.WWW-US-99.M
# Jan 2001                                          3191.0
# Feb 2001                                          2697.0
# ...                                                  ...
# Jul 2016                                          3658.0
# Aug 2016                                          3722.0
# Sep 2016                                          3407.0
# Oct 2016                                          3176.0
# Nov 2016                                          3391.0
#
#                                          9
# description  United States : other biomass
# units               thousand megawatthours
# source key            ELEC.GEN.WAS-US-99.M
# Jan 2001                            1209.0
# Feb 2001                            1096.0
# ...                                    ...
# Jul 2016                            1840.0
# Aug 2016                            1860.0
# Sep 2016                            1757.0
# Oct 2016                            1693.0
# Nov 2016                            1891.0
#
# [194 rows x 6 columns]>

# %%
# Adicionando uma coluna nova com as datas
df_energia3.insert(loc=0, column='Data', value=nova_coluna)
df_energia3.head()
# Out:
#                 Data                                 3  \
# description     Data  United States : other renewables
# units                           thousand megawatthours
# source key                        ELEC.GEN.AOR-US-99.M
# Jan 2001     Jan2001                            6025.0
# Feb 2001     Feb2001                            5310.0
#
#                                   4                                        5  \
# description    United States : wind  United States : all utility-scale solar
# units        thousand megawatthours                   thousand megawatthours
# source key     ELEC.GEN.WND-US-99.M                     ELEC.GEN.SUN-US-99.M
# Jan 2001                      389.0                                      7.0
# Feb 2001                      431.0                                     13.0
#
#                                       6  \
# description  United States : geothermal
# units            thousand megawatthours
# source key         ELEC.GEN.GEO-US-99.M
# Jan 2001                         1229.0
# Feb 2001                         1073.0
#
#                                                        8  \
# description  United States : wood and wood-derived fuels
# units                             thousand megawatthours
# source key                          ELEC.GEN.WWW-US-99.M
# Jan 2001                                          3191.0
# Feb 2001                                          2697.0
#
#                                          9
# description  United States : other biomass
# units               thousand megawatthours
# source key            ELEC.GEN.WAS-US-99.M
# Jan 2001                            1209.0
# Feb 2001                            1096.0

# %%
#Verificando a tabelas
df_energia3.head()
# Out:
#                 Data                                 3  \
# description     Data  United States : other renewables
# units                           thousand megawatthours
# source key                        ELEC.GEN.AOR-US-99.M
# Jan 2001     Jan2001                            6025.0
# Feb 2001     Feb2001                            5310.0
#
#                                   4                                        5  \
# description    United States : wind  United States : all utility-scale solar
# units        thousand megawatthours                   thousand megawatthours
# source key     ELEC.GEN.WND-US-99.M                     ELEC.GEN.SUN-US-99.M
# Jan 2001                      389.0                                      7.0
# Feb 2001                      431.0                                     13.0
#
#                                       6  \
# description  United States : geothermal
# units            thousand megawatthours
# source key         ELEC.GEN.GEO-US-99.M
# Jan 2001                         1229.0
# Feb 2001                         1073.0
#
#                                                        8  \
# description  United States : wood and wood-derived fuels
# units                             thousand megawatthours
# source key                          ELEC.GEN.WWW-US-99.M
# Jan 2001                                          3191.0
# Feb 2001                                          2697.0
#
#                                          9
# description  United States : other biomass
# units               thousand megawatthours
# source key            ELEC.GEN.WAS-US-99.M
# Jan 2001                            1209.0
# Feb 2001                            1096.0

# %%
# Verificando o final da coluna
df_energia3.tail()
# Out:
#              Data        3        4       5       6       8       9
# Jul 2016  Jul2016  28372.0  17618.0  3945.0  1311.0  3658.0  1840.0
# Aug 2016  Aug2016  24465.0  13589.0  3969.0  1324.0  3722.0  1860.0
# Sep 2016  Sep2016  26529.0  16404.0  3635.0  1327.0  3407.0  1757.0
# Oct 2016  Oct2016  29749.0  20335.0  3191.0  1353.0  3176.0  1693.0
# Nov 2016  Nov2016  28819.0  19406.0  2767.0  1364.0  3391.0  1891.0

# %%
# Montando a tabela
df_tabela=df_energia3[['Data',3]]
df_tabela
# Out:
#                 Data                                 3
# description     Data  United States : other renewables
# units                           thousand megawatthours
# source key                        ELEC.GEN.AOR-US-99.M
# Jan 2001     Jan2001                            6025.0
# Feb 2001     Feb2001                            5310.0
# ...              ...                               ...
# Jul 2016     Jul2016                           28372.0
# Aug 2016     Aug2016                           24465.0
# Sep 2016     Sep2016                           26529.0
# Oct 2016     Oct2016                           29749.0
# Nov 2016     Nov2016                           28819.0
#
# [194 rows x 2 columns]

# %%
# Retirando todos os valores NaN
df_tabela1 = df_tabela.dropna()
df_tabela1
# Out:
#                 Data                                 3
# description     Data  United States : other renewables
# units                           thousand megawatthours
# source key                        ELEC.GEN.AOR-US-99.M
# Jan 2001     Jan2001                            6025.0
# Feb 2001     Feb2001                            5310.0
# ...              ...                               ...
# Jul 2016     Jul2016                           28372.0
# Aug 2016     Aug2016                           24465.0
# Sep 2016     Sep2016                           26529.0
# Oct 2016     Oct2016                           29749.0
# Nov 2016     Nov2016                           28819.0
#
# [194 rows x 2 columns]

# %%
# Excluindo as linhas indices units e source key  
df_tabela1.drop('units', axis=0, inplace=True) # inplace = a mudança é realizada - axis=0 retiro a linha***** - acertar depois quando for rodar 
df_tabela1.drop('source key', axis=0, inplace=True)
df_tabela1.drop('description', axis=0, inplace=True)
df_tabela1
# Out:
#              Data        3
# Jan 2001  Jan2001   6025.0
# Feb 2001  Feb2001   5310.0
# Mar 2001  Mar2001   5795.0
# Apr 2001  Apr2001   5827.0
# May 2001  May2001   5738.0
# ...           ...      ...
# Jul 2016  Jul2016  28372.0
# Aug 2016  Aug2016  24465.0
# Sep 2016  Sep2016  26529.0
# Oct 2016  Oct2016  29749.0
# Nov 2016  Nov2016  28819.0
#
# [191 rows x 2 columns]

# %%
# Precisamos converter as colunas  para inteiro - int
#df_tabela1[3] = df_tabela1[3].str.replace('.','').astype(int)
df_tabela1[3] = df_tabela1[3].astype(int)

# %%
# Vamos analisar os tipos das colunas
df_tabela1.info
# Out:
# <bound method DataFrame.info of              Data      3
# Jan 2001  Jan2001   6025
# Feb 2001  Feb2001   5310
# Mar 2001  Mar2001   5795
# Apr 2001  Apr2001   5827
# May 2001  May2001   5738
# ...           ...    ...
# Jul 2016  Jul2016  28372
# Aug 2016  Aug2016  24465
# Sep 2016  Sep2016  26529
# Oct 2016  Oct2016  29749
# Nov 2016  Nov2016  28819
#
# [191 rows x 2 columns]>

# %%
# Montando o gráfico para duas colunas - 
fi1=df_tabela1.plot.bar(facecolor='teal',figsize=(40,20), width = 0.5)
plt.title('Gráfico de coluna para trabalho com o Seaborn', fontsize=18, color='orange')
plt.xticks (color='orange', rotation= 35)
plt.yticks (color='orange')
plt.xlabel('Datas',color='orange')
plt.ylabel('Outras energias renováveis',color='orange')
plt.legend() 
plt.show()

# %%
df_tabela1.head(40)
# Out:
#              Data     3
# Jan 2001  Jan2001  6025
# Feb 2001  Feb2001  5310
# Mar 2001  Mar2001  5795
# Apr 2001  Apr2001  5827
# May 2001  May2001  5738
# Jun 2001  Jun2001  5964
# Jul 2001  Jul2001  6244
# Aug 2001  Aug2001  6293
# Sep 2001  Sep2001  5770
# Oct 2001  Oct2001  6050
# Nov 2001  Nov2001  5713
# Dec 2001  Dec2001  6038
# Jan 2002  Jan2002  6599
# Feb 2002  Feb2002  5800
# Mar 2002  Mar2002  6354
# Apr 2002  Apr2002  6543
# May 2002  May2002  6760
# Jun 2002  Jun2002  7066
# Jul 2002  Jul2002  7056
# Aug 2002  Aug2002  7044
# Sep 2002  Sep2002  6582
# Oct 2002  Oct2002  6559
# Nov 2002  Nov2002  6250
# Dec 2002  Dec2002  6497
# Jan 2003  Jan2003  6500
# Feb 2003  Feb2003  5962
# Mar 2003  Mar2003  6719
# Apr 2003  Apr2003  6674
# May 2003  May2003  6473
# Jun 2003  Jun2003  6678
# Jul 2003  Jul2003  7009
# Aug 2003  Aug2003  6790
# Sep 2003  Sep2003  6537
# Oct 2003  Oct2003  6548
# Nov 2003  Nov2003  6531
# Dec 2003  Dec2003  7067
# Jan 2004  Jan2004  6888
# Feb 2004  Feb2004  6489
# Mar 2004  Mar2004  7001
# Apr 2004  Apr2004  6895

# %%
# Exibir o gráfico de linhas com marcação em cada ponto separado por dada

# Selecionando dados - de 2016
ano2016=df_tabela1.loc[(df_tabela1['Data']>='Jan 2016') & (df_tabela1['Data']<='Dec 2016') ]
ano2016


#sns.pointplot(x='Data',y=3, data=dez2016)
#Ajustando as Legendas (Deixando os anos tombados)
#plt.xticks(rotation=65)
#plt.show()
# Out:
# Empty DataFrame
# Columns: [Data, 3]
# Index: []

# %%
# Montando o gráfico para duas colunas - 
fi1=df_tabela1.plot.line(color='g',figsize=(20,10))
plt.title('Gráfico de coluna para trabalho com o Seaborn', fontsize=18, color='orange')
plt.xticks (color='orange', rotation= 35)
plt.yticks (color='orange')
plt.xlabel('Datas',color='orange')
plt.ylabel('Outras energias renováveis',color='orange')
plt.grid(True)
plt.legend() 
plt.show()

# %%
# Montando todos os Gráficos para comparação das Energias Renováveis utilizadas nos USA

# Montando a tabela Geral
df_geral=df_energia3[['Data',3,4,5,6,8,9]]
df_geral
# Out:
#                 Data                                 3  \
# description     Data  United States : other renewables
# units                           thousand megawatthours
# source key                        ELEC.GEN.AOR-US-99.M
# Jan 2001     Jan2001                            6025.0
# Feb 2001     Feb2001                            5310.0
# ...              ...                               ...
# Jul 2016     Jul2016                           28372.0
# Aug 2016     Aug2016                           24465.0
# Sep 2016     Sep2016                           26529.0
# Oct 2016     Oct2016                           29749.0
# Nov 2016     Nov2016                           28819.0
#
#                                   4                                        5  \
# description    United States : wind  United States : all utility-scale solar
# units        thousand megawatthours                   thousand megawatthours
# source key     ELEC.GEN.WND-US-99.M                     ELEC.GEN.SUN-US-99.M
# Jan 2001                      389.0                                      7.0
# Feb 2001                      431.0                                     13.0
# ...                             ...                                      ...
# Jul 2016                    17618.0                                   3945.0
# Aug 2016                    13589.0                                   3969.0
# Sep 2016                    16404.0                                   3635.0
# Oct 2016                    20335.0                                   3191.0
# Nov 2016                    19406.0                                   2767.0
#
#                                       6  \
# description  United States : geothermal
# units            thousand megawatthours
# source key         ELEC.GEN.GEO-US-99.M
# Jan 2001                         1229.0
# Feb 2001                         1073.0
# ...                                 ...
# Jul 2016                         1311.0
# Aug 2016                         1324.0
# Sep 2016                         1327.0
# Oct 2016                         1353.0
# Nov 2016                         1364.0
#
#                                                        8  \
# description  United States : wood and wood-derived fuels
# units                             thousand megawatthours
# source key                          ELEC.GEN.WWW-US-99.M
# Jan 2001                                          3191.0
# Feb 2001                                          2697.0
# ...                                                  ...
# Jul 2016                                          3658.0
# Aug 2016                                          3722.0
# Sep 2016                                          3407.0
# Oct 2016                                          3176.0
# Nov 2016                                          3391.0
#
#                                          9
# description  United States : other biomass
# units               thousand megawatthours
# source key            ELEC.GEN.WAS-US-99.M
# Jan 2001                            1209.0
# Feb 2001                            1096.0
# ...                                    ...
# Jul 2016                            1840.0
# Aug 2016                            1860.0
# Sep 2016                            1757.0
# Oct 2016                            1693.0
# Nov 2016                            1891.0
#
# [194 rows x 7 columns]

# %%
# Excluindo as linhas indices units e source key  
df_geral.drop('units', axis=0, inplace=True) # inplace = a mudança é realizada - axis=0 retiro a linha***** - acertar depois quando for rodar 
df_geral.drop('source key', axis=0, inplace=True)
df_geral.drop('description', axis=0, inplace=True)
df_geral
# Out:
#              Data        3        4       5       6       8       9
# Jan 2001  Jan2001   6025.0    389.0     7.0  1229.0  3191.0  1209.0
# Feb 2001  Feb2001   5310.0    431.0    13.0  1073.0  2697.0  1096.0
# Mar 2001  Mar2001   5795.0    532.0    31.0  1190.0  2853.0  1189.0
# Apr 2001  Apr2001   5827.0    685.0    39.0  1095.0  2821.0  1187.0
# May 2001  May2001   5738.0    635.0    81.0  1071.0  2740.0  1211.0
# ...           ...      ...      ...     ...     ...     ...     ...
# Jul 2016  Jul2016  28372.0  17618.0  3945.0  1311.0  3658.0  1840.0
# Aug 2016  Aug2016  24465.0  13589.0  3969.0  1324.0  3722.0  1860.0
# Sep 2016  Sep2016  26529.0  16404.0  3635.0  1327.0  3407.0  1757.0
# Oct 2016  Oct2016  29749.0  20335.0  3191.0  1353.0  3176.0  1693.0
# Nov 2016  Nov2016  28819.0  19406.0  2767.0  1364.0  3391.0  1891.0
#
# [191 rows x 7 columns]

# %%
# Precisamos converter as colunas de object para inteiro - int
df_geral[3] = df_geral[3].astype(int)
df_geral[4] = df_geral[4].astype(int)
df_geral[5] = df_geral[5].astype(int)
df_geral[6] = df_geral[6].astype(int)
df_geral[8] = df_geral[8].astype(int)
df_geral[9] = df_geral[9].astype(int)

# %%
# Vamos analisar os tipos das colunas
df_geral.info
# Out:
# <bound method DataFrame.info of              Data      3      4     5     6     8     9
# Jan 2001  Jan2001   6025    389     7  1229  3191  1209
# Feb 2001  Feb2001   5310    431    13  1073  2697  1096
# Mar 2001  Mar2001   5795    532    31  1190  2853  1189
# Apr 2001  Apr2001   5827    685    39  1095  2821  1187
# May 2001  May2001   5738    635    81  1071  2740  1211
# ...           ...    ...    ...   ...   ...   ...   ...
# Jul 2016  Jul2016  28372  17618  3945  1311  3658  1840
# Aug 2016  Aug2016  24465  13589  3969  1324  3722  1860
# Sep 2016  Sep2016  26529  16404  3635  1327  3407  1757
# Oct 2016  Oct2016  29749  20335  3191  1353  3176  1693
# Nov 2016  Nov2016  28819  19406  2767  1364  3391  1891
#
# [191 rows x 7 columns]>

# %%
# Renomeando as colunas
df_geral.rename(columns={'Data': 'Datas',3: 'Outras',4: 'Eolica',5: 'Solar',6: 'Termica',8: 'Madeiras e Derivados',9: 'Biomassa',}, inplace = True)
df_geral
# Out:
#             Datas  Outras  Eolica  Solar  Termica  Madeiras e Derivados  \
# Jan 2001  Jan2001    6025     389      7     1229                  3191
# Feb 2001  Feb2001    5310     431     13     1073                  2697
# Mar 2001  Mar2001    5795     532     31     1190                  2853
# Apr 2001  Apr2001    5827     685     39     1095                  2821
# May 2001  May2001    5738     635     81     1071                  2740
# ...           ...     ...     ...    ...      ...                   ...
# Jul 2016  Jul2016   28372   17618   3945     1311                  3658
# Aug 2016  Aug2016   24465   13589   3969     1324                  3722
# Sep 2016  Sep2016   26529   16404   3635     1327                  3407
# Oct 2016  Oct2016   29749   20335   3191     1353                  3176
# Nov 2016  Nov2016   28819   19406   2767     1364                  3391
#
#           Biomassa
# Jan 2001      1209
# Feb 2001      1096
# Mar 2001      1189
# Apr 2001      1187
# May 2001      1211
# ...            ...
# Jul 2016      1840
# Aug 2016      1860
# Sep 2016      1757
# Oct 2016      1693
# Nov 2016      1891
#
# [191 rows x 7 columns]

# %%
# Montando o gráfico - 
fi1=df_geral.plot.line(figsize=(20,10))
plt.title('Gráfico de coluna para trabalho com o Seaborn', fontsize=18, color='orange')
plt.xticks (color='orange', rotation= 35)
plt.yticks (color='orange')
plt.xlabel('Datas',color='orange')
plt.ylabel('Energias renováveis',color='orange')
plt.grid(True)
plt.legend() 
plt.show()

# %%
#Investigando os tipos de energia
sns.set(rc={'figure.figsize':(20,12)})
ax = sns.lineplot(x='Datas', y='Eolica', data=df_geral) # hue ='Promo', style='Promo', ci=False, markers=True
#plt.xticks (rotation= 35)

# %%
#Vamos investigar a distribuição da Energia Eólica - Transformando em Array ou Lista
x = df_geral['Eolica'].values
x
# Out:
# array([  389,   431,   532,   685,   635,   670,   635,   577,   490,
#          607,   470,   616,   811,   714,   852,  1024,  1078,  1126,
#          890,   977,   736,   734,   656,   755,   632,   745,  1036,
#         1093,  1006,  1047,   953,   815,   895,   897,   961,  1105,
#          999,  1022,  1291,  1295,  1702,  1397,  1164,  1051,  1090,
#         1029,   932,  1172,  1132,   966,  1561,  1698,  1746,  1797,
#         1421,  1138,  1468,  1446,  1610,  1828,  2383,  1922,  2359,
#         2472,  2459,  2052,  1955,  1655,  1879,  2442,  2540,  2472,
#         2452,  2520,  3047,  3172,  2952,  2620,  2158,  2699,  2867,
#         3377,  3095,  3490,  4273,  3852,  4782,  5225,  5340,  5140,
#         4008,  3264,  3111,  4756,  4994,  6616,  5951,  5852,  7099,
#         7458,  6262,  5599,  4955,  5464,  4651,  6814,  6875,  6906,
#         6854,  5432,  8589,  9764,  8698,  8049,  6724,  6686,  7106,
#         7944,  9748,  9059,  8550, 10452, 10545, 12422, 11772, 10985,
#         7489,  7474,  6869, 10525, 12439, 10656, 13631, 11052, 14027,
#        12709, 12540, 11972,  8823,  8469,  8790, 12636, 11648, 14524,
#        14739, 14076, 15756, 17476, 16239, 13748, 11094,  9634, 11674,
#        13635, 15803, 13967, 17911, 14009, 17736, 18636, 15601, 15799,
#        12187, 10171, 11520, 14508, 18867, 14711, 15162, 14922, 15308,
#        17867, 17151, 13421, 13675, 13080, 13972, 16380, 19682, 20098,
#        18466, 20138, 21939, 20799, 18848, 16303, 17618, 13589, 16404,
#        20335, 19406])

# %%
#Vamos investigar a distribuição da Energia Eólica
x = df_geral['Eolica'].values
sns.distplot(x, rug=True, color='green',
             hist_kws={'color':'orange'},
             kde_kws={'color':'blue', 'lw':4});
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(x=df_geral.Eolica);
sns.swarmplot(x=df_geral.Eolica,
              color='orange')

# %%
sns.scatterplot(x='Datas', y='Eolica', data=df_geral);

# %%
# Em quais estados estão estas escolas?
df_geral['Eolica'].value_counts()
# Out:
# 635      2
# 2472     2
# 389      1
# 13631    1
# 11772    1
#         ..
# 1655     1
# 1879     1
# 2442     1
# 2540     1
# 19406    1
# Name: Eolica, Length: 189, dtype: int64

# %%
# Detalhes dos dados
# Descreve as colunas numéricas
df_geral.describe()
# Out:
#              Outras        Eolica        Solar      Termica  \
# count    191.000000    191.000000   191.000000   191.000000
# mean   13551.397906   7069.256545   514.329843  1252.607330
# std     7229.038629   6197.736678   889.672359    70.466175
# min     5310.000000    389.000000     3.000000  1063.000000
# 25%     7140.000000   1293.000000    40.000000  1212.500000
# 50%    11100.000000   5225.000000    85.000000  1255.000000
# 75%    19006.000000  12430.500000   462.000000  1303.000000
# max    31084.000000  21939.000000  3969.000000  1394.000000
#
#        Madeiras e Derivados     Biomassa
# count            191.000000   191.000000
# mean            3212.214660  1502.884817
# std              232.939208   219.970949
# min             2664.000000  1086.000000
# 25%             3054.000000  1307.000000
# 50%             3213.000000  1501.000000
# 75%             3359.500000  1690.500000
# max             3807.000000  1989.000000

# %%
#Qual o total de Energia Eolica Gerada?
df_geral['Eolica'].sum()
# Out:
# 1350228

# %%
#Qual o total de Energia Solar Gerada?
df_geral['Solar'].sum()
# Out:
# 98237

# %%
#Qual o total de Energia por Biomassa Gerada?
df_geral['Biomassa'].sum()
# Out:
# 287051

# %%
#Qual o total de Energia por Madeira Gerada?
df_geral['Madeiras e Derivados'].sum()
# Out:
# 613533

# %%
#Qual o total de Outras Energias Geradas?
df_geral['Outras'].sum()
# Out:
# 2588317

# %%
# Criando o conjunto de dados
total= ['Outras','Madeiras e Derivados','Biomassa','Solar','Eolica']
valores=[2588317, 613533, 287051, 98237, 1350228]
explode = (0,0,0.2,0,0)

# Criando a figura para a plotagem
plt.subplots(figsize=(7,7))

# Fazendo um gráfico de Pizza para melhor visualizacao
plt.pie(x= valores, labels=total, explode=explode, autopct='%1.1f%%', startangle=90)

# Mostrando o grafico
plt.show()

# %%
# Montando o gráfico de colunas - 
fi3=df_geral['Solar'].plot.bar(facecolor='red',figsize=(40,20), width = 0.5)
plt.title('Gráfico de coluna para trabalho com o Seaborn', fontsize=18, color='orange')
plt.xticks (color='orange', rotation= 35)
plt.yticks (color='orange')
plt.xlabel('Datas',color='orange')
plt.ylabel('Energia Solar',color='orange')
plt.grid(True)
plt.legend() 
plt.show()

# %%
# Montando o gráfico de colunas - 
fi4=df_geral['Eolica'].plot.bar(facecolor='purple',figsize=(40,20), width = 0.5)
plt.title('Gráfico de coluna para trabalho com o Seaborn', fontsize=18, color='orange')
plt.xticks (color='orange', rotation= 35)
plt.yticks (color='orange')
plt.xlabel('Datas',color='orange')
plt.ylabel('Energia Eolica',color='orange')
plt.grid(True)
plt.legend() 
plt.show()

# %%
# Montando o gráfico de colunas - 
fi4=df_geral['Biomassa'].plot.bar(facecolor='green',figsize=(40,20), width = 0.5)
plt.title('Gráfico de coluna para trabalho com o Seaborn', fontsize=18, color='orange')
plt.xticks (color='orange', rotation= 35)
plt.yticks (color='orange')
plt.xlabel('Datas',color='orange')
plt.ylabel('Energia Biomassa',color='orange')
plt.grid(True)
plt.legend() 
plt.show()

# %%
# Montando o gráfico de colunas - 
fi5=df_geral['Madeiras e Derivados'].plot.bar(facecolor='orange',figsize=(40,20), width = 0.5)
plt.title('Gráfico de coluna para trabalho com o Seaborn', fontsize=18, color='orange')
plt.xticks (color='orange', rotation= 35)
plt.yticks (color='orange')
plt.xlabel('Datas',color='orange')
plt.ylabel('Madeiras e Derivados',color='orange')
plt.grid(True)
plt.legend() 
plt.show()
